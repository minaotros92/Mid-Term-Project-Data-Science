# %% [markdown]
# Import Packages & Load CSV file:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Airbnb_data = pd.read_csv('Aemf1.csv')
Airbnb_data
# Out:
#             City       Price      Day        Room Type  Shared Room  \
# 0      Amsterdam  194.033698  Weekday     Private room        False
# 1      Amsterdam  344.245776  Weekday     Private room        False
# 2      Amsterdam  264.101422  Weekday     Private room        False
# 3      Amsterdam  433.529398  Weekday     Private room        False
# 4      Amsterdam  485.552926  Weekday     Private room        False
# ...          ...         ...      ...              ...          ...
# 41709     Vienna  715.938574  Weekend  Entire home/apt        False
# 41710     Vienna  304.793960  Weekend  Entire home/apt        False
# 41711     Vienna  637.168969  Weekend  Entire home/apt        False
# 41712     Vienna  301.054157  Weekend     Private room        False
# 41713     Vienna  133.230489  Weekend     Private room        False
#
#        Private Room  Person Capacity  Superhost  Multiple Rooms  Business  \
# 0              True              2.0      False               1         0
# ...

# %%
Airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41714 entries, 0 to 41713
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   City                         41714 non-null  object
#  1   Price                        41714 non-null  float64
#  2   Day                          41714 non-null  object
#  3   Room Type                    41714 non-null  object
#  4   Shared Room                  41714 non-null  bool
#  5   Private Room                 41714 non-null  bool
#  6   Person Capacity              41714 non-null  float64
#  7   Superhost                    41714 non-null  bool
#  8   Multiple Rooms               41714 non-null  int64
#  9   Business                     41714 non-null  int64
#  10  Cleanliness Rating           41714 non-null  float64
#  11  Guest Satisfaction           41714 non-null  float64
#  12  Bedrooms                     41714 non-null  int64
# ...

# %%
Airbnb_data.head(10)
# Out:
#         City        Price      Day        Room Type  Shared Room  \
# 0  Amsterdam   194.033698  Weekday     Private room        False
# 1  Amsterdam   344.245776  Weekday     Private room        False
# 2  Amsterdam   264.101422  Weekday     Private room        False
# 3  Amsterdam   433.529398  Weekday     Private room        False
# 4  Amsterdam   485.552926  Weekday     Private room        False
# 5  Amsterdam   552.808567  Weekday     Private room        False
# 6  Amsterdam   215.124317  Weekday     Private room        False
# 7  Amsterdam  2771.307384  Weekday  Entire home/apt        False
# 8  Amsterdam  1001.804420  Weekday  Entire home/apt        False
# 9  Amsterdam   276.521454  Weekday     Private room        False
#
#    Private Room  Person Capacity  Superhost  Multiple Rooms  Business  \
# 0          True              2.0      False               1         0
# 1          True              4.0      False               0         0
# ...

# %%
Airbnb_data.tail(10)
# Out:
#          City       Price      Day        Room Type  Shared Room  \
# 41704  Vienna  463.501858  Weekend  Entire home/apt        False
# 41705  Vienna  727.391721  Weekend  Entire home/apt        False
# 41706  Vienna  718.275951  Weekend  Entire home/apt        False
# 41707  Vienna  115.933899  Weekend     Private room        False
# 41708  Vienna  750.765491  Weekend  Entire home/apt        False
# 41709  Vienna  715.938574  Weekend  Entire home/apt        False
# 41710  Vienna  304.793960  Weekend  Entire home/apt        False
# 41711  Vienna  637.168969  Weekend  Entire home/apt        False
# 41712  Vienna  301.054157  Weekend     Private room        False
# 41713  Vienna  133.230489  Weekend     Private room        False
#
#        Private Room  Person Capacity  Superhost  Multiple Rooms  Business  \
# 41704         False              5.0      False               1         0
# 41705         False              6.0      False               0         1
# ...

# %%
Airbnb_data.isnull().sum
# Out:
# <bound method DataFrame.sum of         City  Price    Day  Room Type  Shared Room  Private Room  \
# 0      False  False  False      False        False         False
# 1      False  False  False      False        False         False
# 2      False  False  False      False        False         False
# 3      False  False  False      False        False         False
# 4      False  False  False      False        False         False
# ...      ...    ...    ...        ...          ...           ...
# 41709  False  False  False      False        False         False
# 41710  False  False  False      False        False         False
# 41711  False  False  False      False        False         False
# 41712  False  False  False      False        False         False
# 41713  False  False  False      False        False         False
#
#        Person Capacity  Superhost  Multiple Rooms  Business  \
# 0                False      False           False     False
# ...

# %%
Airbnb_data.isnull().sum()
# Out:
# City                           0
# Price                          0
# Day                            0
# Room Type                      0
# Shared Room                    0
# Private Room                   0
# Person Capacity                0
# Superhost                      0
# Multiple Rooms                 0
# Business                       0
# Cleanliness Rating             0
# Guest Satisfaction             0
# Bedrooms                       0
# City Center (km)               0
# Metro Distance (km)            0
# Attraction Index               0
# Normalised Attraction Index    0
# Restraunt Index                0
# Normalised Restraunt Index     0
# dtype: int64

# %% [markdown]
# #so no null in the data

# %% [markdown]
# EDA Using Visualizationis:

# %%
Airbnb_data.describe()
# Out:
#               Price  Person Capacity  Multiple Rooms      Business  \
# count  41714.000000     41714.000000    41714.000000  41714.000000
# mean     260.094423         3.237235        0.295273      0.341180
# std      279.408493         1.299459        0.456171      0.474112
# min       34.779339         2.000000        0.000000      0.000000
# 25%      144.016085         2.000000        0.000000      0.000000
# 50%      203.819274         3.000000        0.000000      0.000000
# 75%      297.373358         4.000000        1.000000      1.000000
# max    18545.450285         6.000000        1.000000      1.000000
#
#        Cleanliness Rating  Guest Satisfaction      Bedrooms  City Center (km)  \
# count        41714.000000        41714.000000  41714.000000      41714.000000
# mean             9.442274           93.103179      1.165939          2.679792
# std              0.889173            8.141745      0.638157          1.996684
# ...

# %% [markdown]
# EDA Using Visualizations:

# %%
Airbnb_data.describe().T
# Out:
#                                count        mean         std        min  \
# Price                        41714.0  260.094423  279.408493  34.779339
# Person Capacity              41714.0    3.237235    1.299459   2.000000
# Multiple Rooms               41714.0    0.295273    0.456171   0.000000
# Business                     41714.0    0.341180    0.474112   0.000000
# Cleanliness Rating           41714.0    9.442274    0.889173   2.000000
# Guest Satisfaction           41714.0   93.103179    8.141745  20.000000
# Bedrooms                     41714.0    1.165939    0.638157   0.000000
# City Center (km)             41714.0    2.679792    1.996684   0.015045
# Metro Distance (km)          41714.0    0.603921    0.706206   0.002301
# Attraction Index             41714.0  293.905990  235.750055  15.152201
# Normalised Attraction Index  41714.0   11.719658    8.379161   0.926301
# Restraunt Index              41714.0  626.692618  520.644720  19.576924
# ...

# %% [markdown]
# Valérie: I renamed Correlation to Scatterplot.  I know you can use a scatterplot to start to "sniff out" correlations in a visual way, but the term correlation also has an underlying mathematical definition (you'll come across Pearson's r, which is one way to calculate correlation between two variables).  Alternatively, you could name it "Examining for correlation between Price and Distance to City Center".

# %%
# Create the scatter plot:
plt.scatter(Airbnb_data['City Center (km)'], Airbnb_data['Price'])

# Labels for both axis:
plt.xlabel('City Center (km)')
plt.ylabel('Price')

# Title for the plot:
plt.title('Scatterplot of Price vs City Center (km))')
plt.show()

# %%
# Calculate the average price for each room type:
average_prices = Airbnb_data.groupby('Room Type')['Price'].mean()

# Creating Bar Plot:
plt.bar(average_prices.index, average_prices)

# Labels:
plt.xlabel('Room Type')
plt.ylabel('Price')

# Plot Title:
plt.title('Average Prices by Room Type')
plt.show()

# %% [markdown]
# Valérie: The below has been commented out as it's not actually representing the Price by City.  A histplot produces a histogram, which is a frequency distribution or "count" distribution.  The below plot therefore is merely showing you the count of listings in each city.  Price doesn't show up anywhere other than in the title you gave this plot.

# %%
#sns.histplot(data = Airbnb_data, x = 'City', bins = 20, binwidth = 1.0, color='Yellow')
#plt.title('Price by city')
#plt.xlabel('City')
#plt.ylabel('Count')
#plt.xticks(rotation=45)
#plt.show()

# %% [markdown]
# Valérie: The plot you created here I think does a better job of exploring price by city, as a scatter plot would've simply looked like a bunch of parallel lines with each city showing a range of prices for its listing.  It would've provided limited info.
#
# The box plot below, however, shows us that each city does have a certain spread in its prices, and quite clearly has outliers.  In other words, prices for AirBnB listings vary *widely* in any given city.

# %%
# Create box Plot
sns.boxplot(data=Airbnb_data, x='City', y='Price', color='orange')
plt.title('Price Distribution Across 9-Cities')
plt.xlabel('City')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Valérie:  I wanted to better understand your comment below.  I don't see plots or any other code to investigate the usefulness of the Room Type column to help support what you said, so I had to create it.
#
# The value_counts below shows us there's not much in the Shared room category, and there's a bit more than 2X the rows with Entire room/apt than with Private room.  So ok, that'll impact somewhat the data we'll see, as it's not an even distribution.  That's ok.

# %%
Airbnb_data['Room Type'].value_counts()
# Out:
# Room Type
# Entire home/apt    28264
# Private room       13134
# Shared room          316
# Name: count, dtype: int64

# %% [markdown]
# Valérie:  I used your previous boxplot on prices across 9 cities to create one for prices across the room types to get an idea of the spread of the data.
#
# When you have a variable like Room Type, and it takes on a number of values (3 in this case: Entire home/apt, Private room, and Shared room) and you get such a big spread of a dependant variable like Price on one or any combination of those values, it would suggest that Room Type on its own won't be very informative.  i.e. if we'd seen more of a "clump" of prices for Entire home/apt, and then another "clump" of prices for Private room, maybe a bit lower on the price axis (given a private room would seem less luxurious than an entire home/apt), and then another "clump" of prices for Shared room, even lower on the price axis, that would be a signal that there's a lot of information to be had from looking at price against Room Type.
#
# What we *do* see is a definite "clump" of prices, lower on the price axis, for Shared room - no surprises there.  What's harder to see is whethere there's a marked spread in pricing between Entire home/apt and Private room.  I'm guessing that's what you were referring to in your comment below when you decided to create the binary column for Entire home/apt.

# %%
# Create box Plot
sns.boxplot(data=Airbnb_data, x='Room Type', y='Price', color='orange')
plt.title('Price Distribution Across Room Types')
plt.xlabel('Room Type')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# I found that the "room type" column is not very informative when assessing correlations, especially for "Entire Home/Apt". Therefore, I have decided to add a new column specifically for "Entire Home/Apt".

# %%
Airbnb_data['Entire home/apt'] = Airbnb_data['Room Type'].apply(lambda x: True if x == 'Entire home/apt' else False)

cols = list(Airbnb_data.columns)

cols.insert(cols.index('Shared Room') - 1, cols.pop(cols.index('Entire home/apt')))

Airbnb_data = Airbnb_data[cols]

Airbnb_data
# Out:
#             City       Price      Day  Entire home/apt        Room Type  \
# 0      Amsterdam  194.033698  Weekday            False     Private room
# 1      Amsterdam  344.245776  Weekday            False     Private room
# 2      Amsterdam  264.101422  Weekday            False     Private room
# 3      Amsterdam  433.529398  Weekday            False     Private room
# 4      Amsterdam  485.552926  Weekday            False     Private room
# ...          ...         ...      ...              ...              ...
# 41709     Vienna  715.938574  Weekend             True  Entire home/apt
# 41710     Vienna  304.793960  Weekend             True  Entire home/apt
# 41711     Vienna  637.168969  Weekend             True  Entire home/apt
# 41712     Vienna  301.054157  Weekend            False     Private room
# 41713     Vienna  133.230489  Weekend            False     Private room
#
#        Shared Room  Private Room  Person Capacity  Superhost  Multiple Rooms  \
# ...

# %%
# Select only numeric columns for correlation
numeric_data = Airbnb_data.select_dtypes(include=[np.number])

# Compute the correlation matrix on numeric data
corr_matrix = numeric_data.corr()

# Proceed with the heatmap
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
print(corr_matrix['Normalised Attraction Index'].sort_values(ascending=False))
# Out:
# Normalised Attraction Index    1.000000
# Attraction Index               0.739850
# Normalised Restraunt Index     0.701388
# Restraunt Index                0.501754
# Price                          0.270958
# Business                       0.020663
# Multiple Rooms                -0.021696
# Guest Satisfaction            -0.024609
# Cleanliness Rating            -0.041859
# Person Capacity               -0.052291
# Bedrooms                      -0.082276
# Metro Distance (km)           -0.236217
# City Center (km)              -0.321315
# Name: Normalised Attraction Index, dtype: float64

# %%
print(corr_matrix['Normalised Restraunt Index'].sort_values(ascending=False))
# Out:
# Normalised Restraunt Index     1.000000
# Normalised Attraction Index    0.701388
# Restraunt Index                0.638430
# Attraction Index               0.561332
# Price                          0.219385
# Business                       0.089935
# Person Capacity               -0.010956
# Multiple Rooms                -0.043169
# Guest Satisfaction            -0.047862
# Cleanliness Rating            -0.047907
# Bedrooms                      -0.076505
# Metro Distance (km)           -0.222897
# City Center (km)              -0.379199
# Name: Normalised Restraunt Index, dtype: float64

# %% [markdown]
# Some results are relatively easy to understand, such as the negative correlation between indexs and the distance to the city center and the subway station. We naturally prefer shorter distances. There is a significant positive correlation between indexs and price. However, it is harder to comprehend the negative correlation between indexs and Guest Satisfaction and Cleanliness Rating, which seems unreasonable for an attraction.

# %% [markdown]
# Valérie: The strong positive correlation between Attraction Index and Restaurant Index would suggest they are collinear and almost aliased (aliasing happens when two supposedly independant variables are so closely aligned they may as well be just one variable... they move together almost all the time).  That's probably because people will often consider restaurants to be attractions (especially if it's a famous restaurant in a famous city), and also because where there's attractions like museums and concert halls, there's restaurants.  They're practically inseparable.  We'd want to just focus on one or the other maybe in our visuals.
#
# Bedrooms and Person Capacity are somewhat correlated in that you list Person Capacity by the number of beds available, which is often in line with the number of bedrooms, but not always (pull-out couches in the living room allow more people to stay, but that doesn't count as an extra bedroom).
#
# No surprise that Guest Satisfaction and Cleanliness rating also have a bit of a correlation at 0.69.
#
# None of the negative correlations have me getting too excited.  The strongest are at -0.47, which is a moderate correlation, normally (depends on context a bit... it's a bit subjective what you consider no/light/moderate/strong correlation).  That -0.47 occurs between Business and Multiple Rooms.  I'd have to re-read the info on this dataset to understand what's meant by Business.  Each row in the dataset represents *one* AirBnB listing.  So why a given listing would have Multiple Rooms listed the opposite of Business (they're binary, 0/1, so the negative correlation implies they're normally opposites of each other), I don't know.  ALSO... I'm not sure what it means to get a correlation number off what is effectively categorical features (Business is 0/1, Multiple Rooms is 0/1, it's just a yes/no).  Correlation, by default, as calculated here (I don't know if it's from numpy) uses Pearson's r.  I don't know how to interpret it for categoricals, especially binary ones.

# %%
print(Airbnb_data.dtypes)
# Out:
# City                            object
# Price                          float64
# Day                             object
# Entire home/apt                   bool
# Room Type                       object
# Shared Room                       bool
# Private Room                      bool
# Person Capacity                float64
# Superhost                         bool
# Multiple Rooms                   int64
# Business                         int64
# Cleanliness Rating             float64
# Guest Satisfaction             float64
# Bedrooms                         int64
# City Center (km)               float64
# Metro Distance (km)            float64
# Attraction Index               float64
# Normalised Attraction Index    float64
# Restraunt Index                float64
# Normalised Restraunt Index     float64
# dtype: object

# %%
Airbnb_data.describe().T
# Out:
#                                count        mean         std        min  \
# Price                        41714.0  260.094423  279.408493  34.779339
# Person Capacity              41714.0    3.237235    1.299459   2.000000
# Multiple Rooms               41714.0    0.295273    0.456171   0.000000
# Business                     41714.0    0.341180    0.474112   0.000000
# Cleanliness Rating           41714.0    9.442274    0.889173   2.000000
# Guest Satisfaction           41714.0   93.103179    8.141745  20.000000
# Bedrooms                     41714.0    1.165939    0.638157   0.000000
# City Center (km)             41714.0    2.679792    1.996684   0.015045
# Metro Distance (km)          41714.0    0.603921    0.706206   0.002301
# Attraction Index             41714.0  293.905990  235.750055  15.152201
# Normalised Attraction Index  41714.0   11.719658    8.379161   0.926301
# Restraunt Index              41714.0  626.692618  520.644720  19.576924
# ...

# %% [markdown]
# Now I'm going to normalize several scoring scales to a range of 0-100. I will refer to the Normalised Attraction Index and Normalised Restaurant Index as a guide. At the same time, I will remove the two indices that have not been normalized.

# %% [markdown]
# Valérie:  I'm not sure I understand why we would scale bedrooms or even, say, Person Capacity, as the numbers are in a similar range (0-10, 2-6, respectively, even Cleanliness rating is 2-10).  This shouldn't produce weird effects with the coefficients.  Of course, they're smaller in range than Guest Satisfaction (where the max is 100), so perhaps it's required.  I don't know.

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

scaler = MinMaxScaler(feature_range=(0, 100))

Airbnb_data[['Cleanliness Rating', 'Bedrooms']] = scaler.fit_transform(Airbnb_data[['Cleanliness Rating', 'Bedrooms']])

# %%
Airbnb_data.describe().T
# Out:
#                                count        mean         std        min  \
# Price                        41714.0  260.094423  279.408493  34.779339
# Person Capacity              41714.0    3.237235    1.299459   2.000000
# Multiple Rooms               41714.0    0.295273    0.456171   0.000000
# Business                     41714.0    0.341180    0.474112   0.000000
# Cleanliness Rating           41714.0   93.028420   11.114663   0.000000
# Guest Satisfaction           41714.0   93.103179    8.141745  20.000000
# Bedrooms                     41714.0   11.659395    6.381567   0.000000
# City Center (km)             41714.0    2.679792    1.996684   0.015045
# Metro Distance (km)          41714.0    0.603921    0.706206   0.002301
# Attraction Index             41714.0  293.905990  235.750055  15.152201
# Normalised Attraction Index  41714.0   11.719658    8.379161   0.926301
# Restraunt Index              41714.0  626.692618  520.644720  19.576924
# ...

# %%
Airbnb_data.to_csv('Airbnb_data_V2.csv', index=False)

# %%
Airbnb_data.dtypes
# Out:
# City                            object
# Price                          float64
# Day                             object
# Entire home/apt                   bool
# Room Type                       object
# Shared Room                       bool
# Private Room                      bool
# Person Capacity                float64
# Superhost                         bool
# Multiple Rooms                   int64
# Business                         int64
# Cleanliness Rating             float64
# Guest Satisfaction             float64
# Bedrooms                       float64
# City Center (km)               float64
# Metro Distance (km)            float64
# Attraction Index               float64
# Normalised Attraction Index    float64
# Restraunt Index                float64
# Normalised Restraunt Index     float64
# dtype: object

# %% [markdown]
# #### Adding Population Data

# %% [markdown]
# Valérie:  Population data may be found in several places.
#
# https://www.statista.com/statistics/1101883/largest-european-cities/
#
# EVERY city in our dataset's City column is listed here in 1000's of inhabitants.  So we can just pluck up the numbers here.

# %%
Airbnb_data.head()
# Out:
#         City       Price      Day  Entire home/apt     Room Type  Shared Room  \
# 0  Amsterdam  194.033698  Weekday            False  Private room        False
# 1  Amsterdam  344.245776  Weekday            False  Private room        False
# 2  Amsterdam  264.101422  Weekday            False  Private room        False
# 3  Amsterdam  433.529398  Weekday            False  Private room        False
# 4  Amsterdam  485.552926  Weekday            False  Private room        False
#
#    Private Room  Person Capacity  Superhost  Multiple Rooms  Business  \
# 0          True              2.0      False               1         0
# 1          True              4.0      False               0         0
# 2          True              2.0      False               0         1
# 3          True              4.0      False               0         1
# 4          True              2.0       True               0         0
#
#    Cleanliness Rating  Guest Satisfaction  Bedrooms  City Center (km)  \
# ...

# %%
Airbnb_data['CityPop1000'] = Airbnb_data['City'].apply(lambda x: 1174 if x == 'Amsterdam' else ' ')
Airbnb_data.head()
# Out:
#         City       Price      Day  Entire home/apt     Room Type  Shared Room  \
# 0  Amsterdam  194.033698  Weekday            False  Private room        False
# 1  Amsterdam  344.245776  Weekday            False  Private room        False
# 2  Amsterdam  264.101422  Weekday            False  Private room        False
# 3  Amsterdam  433.529398  Weekday            False  Private room        False
# 4  Amsterdam  485.552926  Weekday            False  Private room        False
#
#    Private Room  Person Capacity  Superhost  Multiple Rooms  ...  \
# 0          True              2.0      False               1  ...
# 1          True              4.0      False               0  ...
# 2          True              2.0      False               0  ...
# 3          True              4.0      False               0  ...
# 4          True              2.0       True               0  ...
#
#    Cleanliness Rating  Guest Satisfaction  Bedrooms  City Center (km)  \
# ...

# %% [markdown]
# Valérie: We'll be able to delete the below code after population data has been entered for each city (so far it's just Amsterdam).

# %%
# I was just checking cities other than Amsterdam did not get any value in CityPop1000.  That worked alright.

Airbnb_data.loc[Airbnb_data['City'] != 'Amsterdam']
#df.loc[df['shield'] > 6]
# Out:
#          City       Price      Day  Entire home/apt        Room Type  \
# 2080   Athens  129.824479  Weekday             True  Entire home/apt
# 2081   Athens  138.963748  Weekday             True  Entire home/apt
# 2082   Athens  156.304923  Weekday             True  Entire home/apt
# 2083   Athens   91.627024  Weekday             True  Entire home/apt
# 2084   Athens   74.051508  Weekday            False     Private room
# ...       ...         ...      ...              ...              ...
# 41709  Vienna  715.938574  Weekend             True  Entire home/apt
# 41710  Vienna  304.793960  Weekend             True  Entire home/apt
# 41711  Vienna  637.168969  Weekend             True  Entire home/apt
# 41712  Vienna  301.054157  Weekend            False     Private room
# 41713  Vienna  133.230489  Weekend            False     Private room
#
#        Shared Room  Private Room  Person Capacity  Superhost  Multiple Rooms  \
# ...

# %% [markdown]
# Valérie: Now, once we have population data for each city, we could think of creating a column like "AirBnb_Listings_per_1Kpop" or something like that.  We obviously can't test every idea we can think of, so we should probably just grab for one or two decent ones and see if they give us much information around pricing, like, do we see markedly higher prices in cities where the AirBnB listings per 1000 inhabitants is lower?
